# %%
from tkinter import *
from tkinter import messagebox
from tkinter import font
from tkinter import ttk

correct_username = "user"
correct_password = "pass"

def check_login():
    username = e1.get()
    password = e2.get()

    if username == correct_username and password == correct_password:
        open_new_window()
    else:
        messagebox.showerror("Login Failed", "Incorrect username or password")

def open_new_window():
    top = Toplevel(root)
    top.title("Tamil Nadu Education Form")
    top.config(bg="lightgray")
    
    bold_font = font.Font(size=12, weight="bold")
    bold_font1 = font.Font(size=12, weight="bold")
    
    # Title Labels
    l1 = Label(top, text="GOVERNMENT OF TAMILNADU", fg="Black", font=bold_font, bg="lightgray")
    l1.grid(row=0, columnspan=4, padx=10, pady=10, sticky="w")
    l2 = Label(top, text="APPLICATION FORM FOR GOVERNMENT TECHNICAL EXAM", fg="Black", font=bold_font, bg="lightgray")
    l2.grid(row=1, columnspan=4, padx=10, pady=10, sticky="w")
    
    # First Name
    l3 = Label(top, text="First Name", fg="Black", font=bold_font1, bg="lightgray")
    l3.grid(row=2, column=0, padx=10, pady=5, sticky="e")
    e1 = Entry(top)
    e1.grid(row=2, column=1, padx=10, pady=5, sticky="w")
    
    # Last Name
    l4 = Label(top, text="Last Name", fg="Black", font=bold_font1, bg="lightgray")
    l4.grid(row=3, column=0, padx=10, pady=5, sticky="e")
    e2 = Entry(top)
    e2.grid(row=3, column=1, padx=10, pady=5, sticky="w")
    
    # Father's Name
    l5 = Label(top, text="Father's Name", fg="Black", font=bold_font1, bg="lightgray")
    l5.grid(row=4, column=0, padx=10, pady=5, sticky="e")
    e3 = Entry(top)
    e3.grid(row=4, column=1, padx=10, pady=5, sticky="w")
    
    # Date of Birth
    l6 = Label(top, text="Date of Birth", fg="Black", font=bold_font1, bg="lightgray")
    l6.grid(row=5, column=0, padx=10, pady=5, sticky="e")
    e4 = Entry(top)
    e4.grid(row=5, column=1, padx=10, pady=5, sticky="w")
    
    # Sex
    l7 = Label(top, text="Sex", fg="Black", font=bold_font1, bg="lightgray")
    l7.grid(row=6, column=0, padx=10, pady=5, sticky="e")
    rd1 = Radiobutton(top, text="Female", value=1, fg="Black", font=bold_font1, bg="lightgray")
    rd1.grid(row=6, column=1, padx=10, pady=5, sticky="w")
    rd2 = Radiobutton(top, text="Male", value=2, fg="Black", font=bold_font1, bg="lightgray")
    rd2.grid(row=6, column=2, padx=10, pady=5, sticky="w")
    rd3 = Radiobutton(top, text="Others", value=3, fg="Black", font=bold_font1, bg="lightgray")
    rd3.grid(row=6, column=3, padx=10, pady=5, sticky="w")
    
    # Age
    l8 = Label(top, text="Age", fg="Black", font=bold_font1, bg="lightgray")
    l8.grid(row=7, column=0, padx=10, pady=5, sticky="e")
    s = Spinbox(top, from_=0, to=70)
    s.grid(row=7, column=1, padx=10, pady=5, sticky="w")
    
    # Permanent Address
    l9 = Label(top, text="Permanent Address", fg="Black", font=bold_font1, bg="lightgray")
    l9.grid(row=8, column=0, padx=10, pady=5, sticky="ne")
    t1 = Text(top, fg="Black", font=bold_font1, width=20, height=5)
    t1.grid(row=8, column=1, padx=10, pady=5, sticky="w")
    
    # Qualification
    l10 = Label(top, text="Qualification", fg="Black", font=bold_font1, bg="lightgray")
    l10.grid(row=9, column=0, padx=10, pady=5, sticky="e")
    dd = ttk.Combobox(top, font=bold_font1, values=["Diploma", "UG", "PG", "PhD"])
    dd.grid(row=9, column=1, padx=10, pady=5, sticky="w")
    
    # Mother Tongue
    l11 = Label(top, text="Mother Tongue", fg="Black", font=bold_font1, bg="lightgray")
    l11.grid(row=10, column=0, padx=10, pady=5, sticky="e")
    ck1 = Checkbutton(top, text="Tamil", fg="Black", font=bold_font1, bg="lightgray")
    ck1.grid(row=10, column=1, padx=5, pady=5, sticky="w")
    ck2 = Checkbutton(top, text="Malayalam", fg="Black", font=bold_font1, bg="lightgray")
    ck2.grid(row=10, column=2, padx=5, pady=5, sticky="w")
    ck3 = Checkbutton(top, text="Hindi", fg="Black", font=bold_font1, bg="lightgray")
    ck3.grid(row=10, column=3, padx=5, pady=5, sticky="w")
    ck4 = Checkbutton(top, text="Telugu", fg="Black", font=bold_font1, bg="lightgray")
    ck4.grid(row=10, column=4, padx=5, pady=5, sticky="w")
    
    # State
    l12 = Label(top, text="State", fg="Black", font=bold_font1, bg="lightgray")
    l12.grid(row=11, column=0, padx=10, pady=5, sticky="e")
    dd = ttk.Combobox(top, font=bold_font1, values=["Tamil Nadu", "Kerala", "Karnataka", "Andhra Pradesh", "Telangana", "Mumbai", "UP"])
    dd.grid(row=11, column=1, padx=10, pady=5, sticky="w")
    
    # Country
    l13 = Label(top, text="Country", fg="Black", font=bold_font1, bg="lightgray")
    l13.grid(row=12, column=0, padx=10, pady=5, sticky="e")
    dd = ttk.Combobox(top, font=bold_font1, values=["Australia", "Berlin", "Canada", "England", "Denmark", "France", "Germany", "India"])
    dd.grid(row=12, column=1, padx=10, pady=5, sticky="w")
    
    # Special Disability
    l14 = Label(top, text="Specially Disabled", fg="Black", font=bold_font1, bg="lightgray")
    l14.grid(row=13, column=0, padx=10, pady=5, sticky="e")
    rd1 = Radiobutton(top, text="Yes", value=1, fg="Black", font=bold_font1, bg="lightgray")
    rd1.grid(row=13, column=1, padx=10, pady=5, sticky="w")
    rd2 = Radiobutton(top, text="No", value=2, fg="Black", font=bold_font1, bg="lightgray")
    rd2.grid(row=13, column=2, padx=10, pady=5, sticky="w")
    
    # Religion
    l15 = Label(top, text="Religion", fg="Black", font=bold_font1, bg="lightgray")
    l15.grid(row=14, column=0, padx=10, pady=5, sticky="e")
    rd1 = Radiobutton(top, text="Christian", value=1, fg="Black", font=bold_font1, bg="lightgray")
    rd1.grid(row=14, column=1, padx=10)
    #submit
    def finish():
        messagebox.showinfo("Successfully Resgister")
    finish=Button(top,text="Finish",command=finish,fg="Black", font=bold_font1)
    finish.grid(row=15,columnspan=2,padx=10,pady=5)


root = Tk()
root.title("Login Form")
root.config(bg="Pink")
frame =Frame(root, padx=200, pady=20)
frame.pack(padx=10, pady=10)
label_username = Label(frame, text="Username")
label_username.grid(row=0, column=0, pady=5)
e1=Entry(frame)
e1.grid(row=0,column=1,pady=5)
label_password=Label(frame,text="Password")
label_password.grid(row=1,column=0,pady=10)
e2=Entry(frame, show="*")
e2.grid(row=1,column=1,pady=5)
submit_button=Button(frame,text="Submit",command=check_login)
submit_button.grid(row=2,columnspan=2,pady=10)
root.mainloop()
